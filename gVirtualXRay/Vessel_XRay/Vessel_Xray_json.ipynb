# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np # Who does not use Numpy?
import matplotlib, json5 # To plot images
import matplotlib.pyplot as plt # Plotting
from matplotlib.colors import LogNorm # Look up table
from utils import set_source_detector, simulate_Xray

font = {'family' : 'serif',
         'size'   : 15
       }
matplotlib.rc('font', **font)
matplotlib.rc('text', usetex=True)

from tifffile import imwrite # Write TIFF files

from gvxrPython3 import gvxr # Simulate X-ray images
import json2gvxr # Set the X-ray simulation environment
# Out:
# SimpleGVXR 2.0.7 (2023-11-06T17:42:00) [Compiler: GNU g++] on Linux
# gVirtualXRay core library (gvxr) 2.0.7 (2023-11-06T17:42:00) [Compiler: GNU g++] on Linux
# Thu Apr 25 15:29:57 2024 (WW) Spekpy is not installed, try Xpecgen instead.
# Thu Apr 25 15:29:57 2024 (WW) Xpecgen is not installed either.

# %% [markdown]
# We added `import json2gvxr` to the list of modules.

# %% [markdown]
# # Create an OpenGL context
#
# To create an OpenGL context, the renderer is either "OPENGL" or "EGL".
# OPENGL is used to create an interactive visualisation window; EGL is used for offline rendering only, e.g. on a supercomputer.

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
r = 50

phi_n = 3
theta_n = 3
phi = np.linspace(0, 2*np.pi, phi_n, endpoint=False)
theta = np.linspace(np.pi/(theta_n+1), np.pi, theta_n, endpoint=False)
# theta = np.pi/(theta_n+1) * np.ones(theta_n)
u, v = np.meshgrid(phi, theta)
x = r*np.cos(u) * np.sin(v) 
y = r*np.sin(u) * np.sin(v) 
z = r*np.cos(v) 
# ax.plot_surface(x, y, z, cmap=plt.cm.YlGnBu_r)
ax.scatter(x,y,z)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Load the json5 file
fname = 'configuration-03.json'
with open(fname) as f:
    params = json5.load(f)


fig, ax = plt.subplots(phi_n, theta_n, figsize=(12,12))

# fig1, ax1 = plt.subplots(phi_n, theta_n, figsize=(12,12))
# fig1.suptitle("Screenshot of the X-ray simulation environment")
# plt.axis('off')
np.set_printoptions(precision=2)
lookAt = np.array([0,0,0])
k = 0
for i in range(theta_n):
    for j in range(phi_n):
        source_position = np.array([x[i,j], y[i,j],z[i,j]])        
        save_path = "output_data/raw_xray_image-"+ str(k).zfill(2) +".tiff"
        x_ray_image=simulate_Xray(params, source_position, lookAt, save_path)
        ax[i,j].imshow(x_ray_image, cmap='gray')
        ax[i,j].set_title(f'theta: {theta[i]:.2f}, phi: {phi[j]:.2f} \n location: {source_position} ')
        k+= 1

        if i==1 and j==1:
            gvxr.displayScene()
            gvxr.renderLoop()
            # screenshot = gvxr.takeScreenshot()
            gvxr.destroyAllWindows()

        # ax1[i,j].imshow(screenshot)
# Out:
# Create an OpenGL context: 512x512
# Set up the beam
# 	Source position: [35.35533905932737, 0.0, 35.35533905932738, 'cm']
# 	Source shape: PointSource
# Set up the detector
# 	Detector position: [-35.35533905932737, 0.0, -35.35533905932738, 'cm']
# 	Detector up vector: [ 7.07e-01 -8.66e-17 -7.07e-01]
# 	Detector number of pixels: [1024, 1024]
# 	Pixel spacing: [0.48828125, 0.48828125, 'mm']
# Move the Vessel to the centre
# Create an OpenGL context: 512x512
# Set up the beam
# 	Source position: [-17.677669529663678, 30.618621784789728, 35.35533905932738, 'cm']
# 	Source shape: PointSource
# Set up the detector
# 	Detector position: [17.677669529663678, -30.618621784789728, -35.35533905932738, 'cm']
# 	Detector up vector: [-0.35  0.61 -0.71]
# 	Detector number of pixels: [1024, 1024]
# 	Pixel spacing: [0.48828125, 0.48828125, 'mm']
# Move the Vessel to the centre
# Thu Apr 25 15:30:02 2024 ---- Create window (ID: -1)
# Thu Apr 25 15:30:02 2024 ---- Initialise GLFW
# Thu Apr 25 15:30:02 2024 ---- Create an OpenGL window with a 3.2 context.
# Thu Apr 25 15:30:02 2024 ---- Make the window's context current
# Thu Apr 25 15:30:02 2024 ---- Initialise GLEW
# Thu Apr 25 15:30:02 2024 ---- OpenGL vendor: Intel
# Thu Apr 25 15:30:02 2024 ---- OpenGL renderer: Mesa Intel(R) Graphics (RPL-P)
# Thu Apr 25 15:30:02 2024 ---- OpenGL version: 4.6 (Core Profile) Mesa 23.2.1-1ubuntu3.1~22.04.2
# Thu Apr 25 15:30:02 2024 ---- Use OpenGL 4.5.
# Thu Apr 25 15:30:02 2024 ---- Initialise the X-ray renderer if needed and if possible
# Thu Apr 25 15:30:02 2024 ---- Initialise the renderer
# Thu Apr 25 15:30:02 2024 ---- file_name:	/home/rslsync/Qubot/Codes/synthetic-ddsa/synthetic-ddsa/vessels/STL/Segmentation_skin.stl	nb_faces:	453480	nb_vertices:	1360440	bounding_box (in cm):	(0.016544, 1.54083, 0.0189968)	(26.1503, 49.0443, 46.9453)
# Thu Apr 25 15:30:02 2024 ---- Create window (ID: -1)
# Thu Apr 25 15:30:02 2024 ---- Initialise GLFW
# Thu Apr 25 15:30:02 2024 ---- Create an OpenGL window with a 3.2 context.
# Thu Apr 25 15:30:02 2024 ---- Make the window's context current
# Thu Apr 25 15:30:02 2024 ---- Initialise GLEW
# Thu Apr 25 15:30:02 2024 ---- OpenGL vendor: Intel
# Thu Apr 25 15:30:02 2024 ---- OpenGL renderer: Mesa Intel(R) Graphics (RPL-P)
# Thu Apr 25 15:30:02 2024 ---- OpenGL version: 4.6 (Core Profile) Mesa 23.2.1-1ubuntu3.1~22.04.2
# Thu Apr 25 15:30:02 2024 ---- Initialise the X-ray renderer if needed and if possible
# Thu Apr 25 15:30:02 2024 ---- Initialise the renderer
# Thu Apr 25 15:30:02 2024 ---- file_name:	/home/rslsync/Qubot/Codes/synthetic-ddsa/synthetic-ddsa/vessels/STL/Segmentation_skin.stl	nb_faces:	453480	nb_vertices:	1360440	bounding_box (in cm):	(0.016544, 1.54083, 0.0189968)	(26.1503, 49.0443, 46.9453)
# Thu Apr 25 15:30:02 2024 ---- Create window (ID: -1)
# Thu Apr 25 15:30:02 2024 ---- Initialise GLFW
# Thu Apr 25 15:30:02 2024 ---- Create an OpenGL window with a 3.2 context.
# Thu Apr 25 15:30:02 2024 ---- Make the window's context current
# Thu Apr 25 15:30:02 2024 ---- Initialise GLEW
# Thu Apr 25 15:30:02 2024 ---- OpenGL vendor: Intel
# Thu Apr 25 15:30:02 2024 ---- OpenGL renderer: Mesa Intel(R) Graphics (RPL-P)
# Thu Apr 25 15:30:02 2024 ---- OpenGL version: 4.6 (Core Profile) Mesa 23.2.1-1ubuntu3.1~22.04.2
# Thu Apr 25 15:30:02 2024 ---- Initialise the X-ray renderer if needed and if possible
# Thu Apr 25 15:30:02 2024 ---- Initialise the renderer
# Thu Apr 25 15:30:02 2024 ---- file_name:	/home/rslsync/Qubot/Codes/synthetic-ddsa/synthetic-ddsa/vessels/STL/Segmentation_skin.stl	nb_faces:	453480	nb_vertices:	1360440	bounding_box (in cm):	(0.016544, 1.54083, 0.0189968)	(26.1503, 49.0443, 46.9453)
# Create an OpenGL context: 512x512
# Set up the beam
# 	Source position: [-17.677669529663703, -30.618621784789713, 35.35533905932738, 'cm']
# 	Source shape: PointSource
# Set up the detector
# 	Detector position: [17.677669529663703, 30.618621784789713, -35.35533905932738, 'cm']
# 	Detector up vector: [-0.35 -0.61 -0.71]
# 	Detector number of pixels: [1024, 1024]
# 	Pixel spacing: [0.48828125, 0.48828125, 'mm']
# Move the Vessel to the centre
# Create an OpenGL context: 512x512
# Set up the beam
# 	Source position: [50.0, 0.0, 3.061616997868383e-15, 'cm']
# 	Source shape: PointSource
# Set up the detector
# 	Detector position: [-50.0, 0.0, -3.061616997868383e-15, 'cm']
# 	Detector up vector: [ 1.61e-16 -1.97e-32 -1.00e+00]
# 	Detector number of pixels: [1024, 1024]
# 	Pixel spacing: [0.48828125, 0.48828125, 'mm']
# Move the Vessel to the centre
# Thu Apr 25 15:30:02 2024 ---- Create window (ID: -1)
# Thu Apr 25 15:30:02 2024 ---- Initialise GLFW
# Thu Apr 25 15:30:02 2024 ---- Create an OpenGL window with a 3.2 context.
# Thu Apr 25 15:30:02 2024 ---- Make the window's context current
# Thu Apr 25 15:30:02 2024 ---- Initialise GLEW
# Thu Apr 25 15:30:02 2024 ---- OpenGL vendor: Intel
# Thu Apr 25 15:30:02 2024 ---- OpenGL renderer: Mesa Intel(R) Graphics (RPL-P)
# Thu Apr 25 15:30:02 2024 ---- OpenGL version: 4.6 (Core Profile) Mesa 23.2.1-1ubuntu3.1~22.04.2
# Thu Apr 25 15:30:02 2024 ---- Initialise the X-ray renderer if needed and if possible
# Thu Apr 25 15:30:02 2024 ---- Initialise the renderer
# Thu Apr 25 15:30:03 2024 ---- file_name:	/home/rslsync/Qubot/Codes/synthetic-ddsa/synthetic-ddsa/vessels/STL/Segmentation_skin.stl	nb_faces:	453480	nb_vertices:	1360440	bounding_box (in cm):	(0.016544, 1.54083, 0.0189968)	(26.1503, 49.0443, 46.9453)
# Thu Apr 25 15:30:03 2024 ---- Create window (ID: -1)
# Thu Apr 25 15:30:03 2024 ---- Initialise GLFW
# Thu Apr 25 15:30:03 2024 ---- Create an OpenGL window with a 3.2 context.
# Thu Apr 25 15:30:03 2024 ---- Make the window's context current
# Thu Apr 25 15:30:03 2024 ---- Initialise GLEW
# Thu Apr 25 15:30:03 2024 ---- OpenGL vendor: Intel
# Thu Apr 25 15:30:03 2024 ---- OpenGL renderer: Mesa Intel(R) Graphics (RPL-P)
# Thu Apr 25 15:30:03 2024 ---- OpenGL version: 4.6 (Core Profile) Mesa 23.2.1-1ubuntu3.1~22.04.2
# Thu Apr 25 15:30:03 2024 ---- Initialise the X-ray renderer if needed and if possible
# Create an OpenGL context: 512x512
# Set up the beam
# 	Source position: [-24.99999999999999, 43.30127018922194, 3.061616997868383e-15, 'cm']
# 	Source shape: PointSource
# Set up the detector
# 	Detector position: [24.99999999999999, -43.30127018922194, -3.061616997868383e-15, 'cm']
# 	Detector up vector: [-8.04e-17  1.39e-16 -1.00e+00]
# 	Detector number of pixels: [1024, 1024]
# 	Pixel spacing: [0.48828125, 0.48828125, 'mm']
# Move the Vessel to the centre
# Thu Apr 25 15:30:03 2024 ---- Initialise the renderer
# Thu Apr 25 15:30:03 2024 ---- file_name:	/home/rslsync/Qubot/Codes/synthetic-ddsa/synthetic-ddsa/vessels/STL/Segmentation_skin.stl	nb_faces:	453480	nb_vertices:	1360440	bounding_box (in cm):	(0.016544, 1.54083, 0.0189968)	(26.1503, 49.0443, 46.9453)
# Thu Apr 25 15:30:06 2024 ---- Destroy all the windows
# Thu Apr 25 15:30:06 2024 ---- Destroy window 0(0x5edb008fb790)
# Thu Apr 25 15:30:06 2024 ---- Destroy window 1(0x5edb023b2850)
# Thu Apr 25 15:30:06 2024 ---- Destroy window 2(0x5edb05ab13e0)
# Thu Apr 25 15:30:06 2024 ---- Destroy window 3(0x5edb07c2cc50)
# Thu Apr 25 15:30:06 2024 ---- Destroy window 4(0x5edb09406c90)
# Thu Apr 25 15:30:06 2024 ---- Create window (ID: -1)
# Thu Apr 25 15:30:06 2024 ---- Initialise GLFW
# Thu Apr 25 15:30:06 2024 ---- Create an OpenGL window with a 3.2 context.
# Thu Apr 25 15:30:06 2024 ---- Make the window's context current
# Thu Apr 25 15:30:06 2024 ---- Initialise GLEW
# Thu Apr 25 15:30:06 2024 ---- OpenGL vendor: Intel
# Thu Apr 25 15:30:06 2024 ---- OpenGL renderer: Mesa Intel(R) Graphics (RPL-P)
# Thu Apr 25 15:30:06 2024 ---- OpenGL version: 4.6 (Core Profile) Mesa 23.2.1-1ubuntu3.1~22.04.2
# Thu Apr 25 15:30:06 2024 ---- Initialise the X-ray renderer if needed and if possible
# Thu Apr 25 15:30:06 2024 ---- Initialise the renderer
# Thu Apr 25 15:30:06 2024 ---- file_name:	/home/rslsync/Qubot/Codes/synthetic-ddsa/synthetic-ddsa/vessels/STL/Segmentation_skin.stl	nb_faces:	453480	nb_vertices:	1360440	bounding_box (in cm):	(0.016544, 1.54083, 0.0189968)	(26.1503, 49.0443, 46.9453)
# Create an OpenGL context: 512x512
# Set up the beam
# 	Source position: [-25.00000000000002, -43.30127018922192, 3.061616997868383e-15, 'cm']
# 	Source shape: PointSource
# Set up the detector
# 	Detector position: [25.00000000000002, 43.30127018922192, -3.061616997868383e-15, 'cm']
# 	Detector up vector: [-8.04e-17 -1.39e-16 -1.00e+00]
# 	Detector number of pixels: [1024, 1024]
# 	Pixel spacing: [0.48828125, 0.48828125, 'mm']
# Move the Vessel to the centre
# Create an OpenGL context: 512x512
# Set up the beam
# 	Source position: [35.35533905932738, 0.0, -35.35533905932737, 'cm']
# 	Source shape: PointSource
# Set up the detector
# 	Detector position: [-35.35533905932738, 0.0, 35.35533905932737, 'cm']
# 	Detector up vector: [-7.07e-01  8.66e-17 -7.07e-01]
# 	Detector number of pixels: [1024, 1024]
# 	Pixel spacing: [0.48828125, 0.48828125, 'mm']
# Move the Vessel to the centre
# Thu Apr 25 15:30:06 2024 ---- Create window (ID: -1)
# Thu Apr 25 15:30:06 2024 ---- Initialise GLFW
# Thu Apr 25 15:30:06 2024 ---- Create an OpenGL window with a 3.2 context.
# Thu Apr 25 15:30:06 2024 ---- Make the window's context current
# Thu Apr 25 15:30:06 2024 ---- Initialise GLEW
# Thu Apr 25 15:30:06 2024 ---- OpenGL vendor: Intel
# Thu Apr 25 15:30:06 2024 ---- OpenGL renderer: Mesa Intel(R) Graphics (RPL-P)
# Thu Apr 25 15:30:06 2024 ---- OpenGL version: 4.6 (Core Profile) Mesa 23.2.1-1ubuntu3.1~22.04.2
# Thu Apr 25 15:30:06 2024 ---- Initialise the X-ray renderer if needed and if possible
# Thu Apr 25 15:30:06 2024 ---- Initialise the renderer
# Thu Apr 25 15:30:06 2024 ---- file_name:	/home/rslsync/Qubot/Codes/synthetic-ddsa/synthetic-ddsa/vessels/STL/Segmentation_skin.stl	nb_faces:	453480	nb_vertices:	1360440	bounding_box (in cm):	(0.016544, 1.54083, 0.0189968)	(26.1503, 49.0443, 46.9453)
# Thu Apr 25 15:30:06 2024 ---- Create window (ID: -1)
# Thu Apr 25 15:30:06 2024 ---- Initialise GLFW
# Thu Apr 25 15:30:06 2024 ---- Create an OpenGL window with a 3.2 context.
# Thu Apr 25 15:30:06 2024 ---- Make the window's context current
# Thu Apr 25 15:30:06 2024 ---- Initialise GLEW
# Thu Apr 25 15:30:06 2024 ---- OpenGL vendor: Intel
# Thu Apr 25 15:30:06 2024 ---- OpenGL renderer: Mesa Intel(R) Graphics (RPL-P)
# Thu Apr 25 15:30:06 2024 ---- OpenGL version: 4.6 (Core Profile) Mesa 23.2.1-1ubuntu3.1~22.04.2
# Thu Apr 25 15:30:06 2024 ---- Initialise the X-ray renderer if needed and if possible
# Thu Apr 25 15:30:06 2024 ---- Initialise the renderer
# Thu Apr 25 15:30:06 2024 ---- file_name:	/home/rslsync/Qubot/Codes/synthetic-ddsa/synthetic-ddsa/vessels/STL/Segmentation_skin.stl	nb_faces:	453480	nb_vertices:	1360440	bounding_box (in cm):	(0.016544, 1.54083, 0.0189968)	(26.1503, 49.0443, 46.9453)
# Create an OpenGL context: 512x512
# Set up the beam
# 	Source position: [-17.67766952966368, 30.61862178478973, -35.35533905932737, 'cm']
# 	Source shape: PointSource
# Set up the detector
# 	Detector position: [17.67766952966368, -30.61862178478973, 35.35533905932737, 'cm']
# 	Detector up vector: [ 0.35 -0.61 -0.71]
# 	Detector number of pixels: [1024, 1024]
# 	Pixel spacing: [0.48828125, 0.48828125, 'mm']
# Move the Vessel to the centre
# Create an OpenGL context: 512x512
# Set up the beam
# 	Source position: [-17.677669529663703, -30.618621784789717, -35.35533905932737, 'cm']
# 	Source shape: PointSource
# Set up the detector
# 	Detector position: [17.677669529663703, 30.618621784789717, 35.35533905932737, 'cm']
# 	Detector up vector: [ 0.35  0.61 -0.71]
# 	Detector number of pixels: [1024, 1024]
# 	Pixel spacing: [0.48828125, 0.48828125, 'mm']
# Move the Vessel to the centre
# Thu Apr 25 15:30:06 2024 ---- Create window (ID: -1)
# Thu Apr 25 15:30:06 2024 ---- Initialise GLFW
# Thu Apr 25 15:30:06 2024 ---- Create an OpenGL window with a 3.2 context.
# Thu Apr 25 15:30:06 2024 ---- Make the window's context current
# Thu Apr 25 15:30:06 2024 ---- Initialise GLEW
# Thu Apr 25 15:30:06 2024 ---- OpenGL vendor: Intel
# Thu Apr 25 15:30:06 2024 ---- OpenGL renderer: Mesa Intel(R) Graphics (RPL-P)
# Thu Apr 25 15:30:06 2024 ---- OpenGL version: 4.6 (Core Profile) Mesa 23.2.1-1ubuntu3.1~22.04.2
# Thu Apr 25 15:30:06 2024 ---- Initialise the X-ray renderer if needed and if possible
# Thu Apr 25 15:30:06 2024 ---- Initialise the renderer
# Thu Apr 25 15:30:06 2024 ---- file_name:	/home/rslsync/Qubot/Codes/synthetic-ddsa/synthetic-ddsa/vessels/STL/Segmentation_skin.stl	nb_faces:	453480	nb_vertices:	1360440	bounding_box (in cm):	(0.016544, 1.54083, 0.0189968)	(26.1503, 49.0443, 46.9453)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
help(gvxr.rotateNode)
# Out:
# Help on function rotateNode in module gvxrPython3._gvxrPython3.temp_gvxrPython3:
#
# rotateNode(*args)
#     Rotate a polygon mesh.
#
#     Parameters
#     ----------
#     * `aLabel` :
#         the label of the polygon mesh to transform
#     * `anAngle` :
#         the rotation angle in degrees
#     * `x` :
#         the component of the rotation vector along the X-axis
#     * `y` :
#         the component of the rotation vector along the Y-axis
#     * `z` :
#         the component of the rotation vector along the Z-axis

# %% [markdown]
# # Display the X-ray image

# %%
plt.figure(figsize=(20, 10))
plt.title("Image simulated using gVirtualXray\nusing a linear colour scale")
plt.imshow(x_ray_image, cmap="gray")
plt.colorbar(orientation='vertical');
plt.show()

# %%
plt.figure(figsize=(20, 10))
plt.title("Image simulated using gVirtualXray\nusing a logarithmic colour scale")
plt.imshow(x_ray_image, cmap="gray", norm=LogNorm(vmin=x_ray_image.min(), vmax=x_ray_image.max()))
plt.colorbar(orientation='vertical');
plt.show()

# %% [markdown]
# # Update the visualisation window

# %%
gvxr.displayScene()
gvxr.renderLoop()
gvxr.destroyAllWindows()
# Out:
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO
# .
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Error: Cannot create the VBO.
# 	- in File: /io/gvxr/src/Graphics/PolygonMesh.cxx
# 	- in Function: display
# 	- at Line: 248
#
# Wed Apr 24 14:57:11 2024 ---- Destroy all the windows
# Wed Apr 24 14:57:11 2024 ---- Destroy window 0(0x598341ba42e0)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 1(0x598341634fe0)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 2(0x598345ca8930)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 3(0x598347bdc160)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 4(0x59834d1f1430)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 5(0x59834e9c25b0)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 6(0x598351990120)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 7(0x598351023740)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 8(0x59834ecf1350)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 9(0x598354ff38d0)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 10(0x59834f155000)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 11(0x59835e661060)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 12(0x5983600b0a80)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 13(0x5983600ad6c0)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 14(0x598364c458e0)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 15(0x598362996ff0)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 16(0x59836c2fe370)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 17(0x59836ea7f120)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 18(0x598370255cc0)
# Wed Apr 24 14:57:11 2024 ---- Destroy window 19(0x598373225250)

# %% [markdown]
# # Interactive visualisation
#
# The user can rotate the 3D scene and zoom-in and -out in the visualisation window.
#
# - Keys are:
#     - Q/Escape: to quit the event loop (does not close the window)
#     - B: display/hide the X-ray beam
#     - W: display the polygon meshes in solid or wireframe
#     - N: display the X-ray image in negative or positive
#     - H: display/hide the X-ray detector
# - Mouse interactions:
#     - Zoom in/out: mouse wheel
#     - Rotation: Right mouse button down + move cursor

# %% [markdown]
# # Take a screenshot
#
# This image can be used in a research paper to illustrate the simulation environment, in which case you may want to change the background colour to white with:

# %%
gvxr.setWindowBackGroundColour(1.0, 1.0, 1.0)

# %% [markdown]
# or dark-grey

# %%
gvxr.setWindowBackGroundColour(0.25, 0.25, 0.25)

# %% [markdown]
# and update the visualisation window

# %%
gvxr.displayScene()

# %% [markdown]
# take the screenshot and save it in a file

# %%
gvxr.displayScene()
screenshot = gvxr.takeScreenshot()
gvxr.destroyAllWindows()
# Out:
# Wed Apr 24 14:27:24 2024 (WW) No active window to use.
# Wed Apr 24 14:27:24 2024 (WW) No active window to hide.
# Wed Apr 24 14:27:24 2024 ---- Destroy all the windows

# %%
plt.imsave("output_data/screenshot-03.png", np.array(screenshot))

# %% [markdown]
# display it using Matplotlib

# %%
plt.figure(figsize=(20, 10))
plt.imshow(screenshot)
plt.title("Screenshot of the X-ray simulation environment")
plt.axis('off');
plt.show()

# %% [markdown]
# ## All done
#
# Destroy the window

# %%
gvxr.destroyAllWindows()
# Out:
# Wed Apr 24 15:07:39 2024 ---- Destroy all the windows
# Wed Apr 24 15:07:39 2024 ---- Destroy window 0(0x5f78ebe7a0b0)
# Wed Apr 24 15:07:39 2024 ---- Destroy window 1(0x5f78ecede180)
# Wed Apr 24 15:07:39 2024 ---- Destroy window 2(0x5f78f10ff4b0)
# Wed Apr 24 15:07:39 2024 ---- Destroy window 3(0x5f78f230b040)
# Wed Apr 24 15:07:39 2024 ---- Destroy window 4(0x5f78f4accfd0)
# Wed Apr 24 15:07:39 2024 ---- Destroy window 5(0x5f78f7aad460)
# Wed Apr 24 15:07:39 2024 ---- Destroy window 6(0x5f78f7156450)
# Wed Apr 24 15:07:39 2024 ---- Destroy window 7(0x5f78f4dfd820)
# Wed Apr 24 15:07:39 2024 ---- Destroy window 8(0x5f78fb191780)
